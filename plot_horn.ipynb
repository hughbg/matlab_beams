# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
from plot_horn import plot_horn

# %%
p = { 'FlareWidth': 2.3,
     'Width': 0.5,
     'FeedWidth': 0.04,
     'FlareHeight': 2.3,
     'Height': 0.5,
     'FeedHeight': 0.2,
     'FlareLength': 3.9,
     'Length': 0.4,
     'FeedOffset0': -0.05,
     'FeedOffset1': 0
     }

plot_horn(p, save_to="demo")
#check_orientation()
